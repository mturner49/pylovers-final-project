# %%
import pip
# pip.main(['install', '{insert_pckg_here}'])
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## Creating Dataframe From Training Csv In Repo:

# %%
train_url = 'https://raw.githubusercontent.com/mturner49/pylovers-final-project/dev/data/train.csv'
test_url = 'https://raw.githubusercontent.com/mturner49/pylovers-final-project/dev/data/test.csv'

training_set = pd.read_csv(train_url, low_memory=False, error_bad_lines=False)
testing_set = pd.read_csv(test_url, low_memory=False, error_bad_lines=False)

train_df = pd.DataFrame(training_set)
test_df = pd.DataFrame(testing_set)

# %%
# replace null values in df w/ values that had most counts for each column
train_df = train_df.apply(lambda x: x.fillna(0) if x.dtype.kind in 'biufc' \
                          else x.fillna(train_df.columns.value_counts().idxmax()))
test_df = test_df.apply(lambda x: x.fillna(0) if x.dtype.kind in 'biufc' \
                          else x.fillna(train_df.columns.value_counts().idxmax()))
# combining the training and test dfs
dfs = [train_df, test_df]
df = pd.concat(dfs)

df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street        Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  LotFrontage      Reg
# 1   2          20       RL         80.0     9600   Pave  LotFrontage      Reg
# 2   3          60       RL         68.0    11250   Pave  LotFrontage      IR1
# 3   4          70       RL         60.0     9550   Pave  LotFrontage      IR1
# 4   5          60       RL         84.0    14260   Pave  LotFrontage      IR1
#
#   LandContour Utilities  ... PoolArea       PoolQC        Fence  MiscFeature  \
# 0         Lvl    AllPub  ...        0  LotFrontage  LotFrontage  LotFrontage
# 1         Lvl    AllPub  ...        0  LotFrontage  LotFrontage  LotFrontage
# 2         Lvl    AllPub  ...        0  LotFrontage  LotFrontage  LotFrontage
# 3         Lvl    AllPub  ...        0  LotFrontage  LotFrontage  LotFrontage
# 4         Lvl    AllPub  ...        0  LotFrontage  LotFrontage  LotFrontage
#
#   MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0       0      2   2008        WD         Normal   208500.0
# 1       0      5   2007        WD         Normal   181500.0
# 2       0      9   2008        WD         Normal   223500.0
# 3       0      2   2006        WD        Abnorml   140000.0
# 4       0     12   2008        WD         Normal   250000.0
#
# [5 rows x 81 columns]

# %% [markdown]
# ## Feature Engineering:

# %%
################## DISREGARD LOGIC BELOW - THIS WILL BE USED ONCE BASE TABLE IS CREATED ######################

# %%
# encode object columns
# enc_df = train_df.select_dtypes(include=['object']).apply(LabelEncoder().fit_transform)
# enc_df

# %%
# add encoded columns back into train df
# train_df[enc_df.columns] = enc_df
# train_df

# %%
# normalize df except for price column
# norm_df = (train_df - train_df.mean()) / (train_df.max() - train_df.min())
